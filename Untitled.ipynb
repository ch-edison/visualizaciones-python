# %%
# load a dataframe containing stock price time-series
from vega_datasets import data
stocks = data.stocks(pivoted=True)

# importing pdvega adds the `vgplot` attribute to pandas objects
import pdvega

stocks.vgplot.line()
# Out:
# <div class="vega-embed" id="e5c2000e-2f20-4e27-bd29-0ad5ecd47357"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
import pandas as pd
import pdvega  # adds vgplot attribute to Pandas objects

data = pd.Series([1,2,3,2,3,4,3,4,5])
data.vgplot()
# Out:
# <div class="vega-embed" id="95f96154-27ef-4677-a039-7fe83dd08a7c"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    2
# 4    3
# 5    4
# 6    3
# 7    4
# 8    5
# dtype: int64

# %%
import json
plot = data.vgplot()
valores = json.dumps(plot.spec, 'plot.json')

# %%
print valores
# Out:
# {"selection": {"grid": {"bind": "scales", "type": "interval"}}, "encoding": {"y": {"field": "0", "type": "quantitative"}, "x": {"field": "index", "type": "quantitative"}}, "height": 300, "width": 450, "$schema": "https://vega.github.io/schema/vega-lite/v2.json", "mark": "line", "data": {"values": [{"index": 0, "0": 1}, {"index": 1, "0": 2}, {"index": 2, "0": 3}, {"index": 3, "0": 2}, {"index": 4, "0": 3}, {"index": 5, "0": 4}, {"index": 6, "0": 3}, {"index": 7, "0": 4}, {"index": 8, "0": 5}]}}
